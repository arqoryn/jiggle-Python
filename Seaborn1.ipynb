# %% [markdown]
# # **Seaborn: Practice 1**

# %% [markdown]
# *   *Author: Mohamad Musadiq (@ARQORYN)*
# *   *Date: 18/03/2026*
# *   *Description: Using Seaborn to visualise Student Performance data from "StudentPerformanceFactors.csv"*
#
#
#
#
#
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8ad7e54e-03e2-447c-97f1-e951df8337bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ad7e54e-03e2-447c-97f1-e951df8337bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("StudentPerformanceFactors.csv")
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
print(df.head())
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %% [markdown]
# # Distribution Plots

# %% [markdown]
# ## Dis Plot (Histogram)

# %%
sns.displot(df["Hours_Studied"], bins=16)

# %%
sns.displot(df["Sleep_Hours"])

# %%
sns.displot(df["Exam_Score"], bins=35)

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(x="Attendance", y="Exam_Score", data=df, hue='School_Type')
# Out:
# <Axes: xlabel='Attendance', ylabel='Exam_Score'>

# %% [markdown]
# ## Joint Plot

# %%
sns.jointplot(x="Attendance", y="Exam_Score", data=df)

# %%
sns.scatterplot(x="Hours_Studied", y="Exam_Score", data=df, hue='Parental_Involvement')
# Out:
# <Axes: xlabel='Hours_Studied', ylabel='Exam_Score'>

# %% [markdown]
# ## Pair Plot

# %%
selected_numerical_cols = ['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores', 'Exam_Score']
sns.pairplot(df[selected_numerical_cols])
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# ## Bar Plots

# %%
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
sns.barplot(x="Parental_Involvement", y="Exam_Score", data=df, palette="winter")
# Out:
# <Axes: xlabel='Parental_Involvement', ylabel='Exam_Score'>

# %%
sns.barplot(x="Learning_Disabilities", y="Exam_Score", data=df, palette="gist_heat")
# Out:
# <Axes: xlabel='Learning_Disabilities', ylabel='Exam_Score'>

# %% [markdown]
# ## Count Plot

# %%
sns.countplot(x="Gender", data= df, palette='hot')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Parental_Involvement", data=df, palette="bone")
# Out:
# <Axes: xlabel='Parental_Involvement', ylabel='count'>

# %%
sns.countplot(x="Parental_Education_Level", data=df, palette="autumn")
# Out:
# <Axes: xlabel='Parental_Education_Level', ylabel='count'>

# %%
sns.countplot(x="Family_Income", data=df, palette="afmhot")
# Out:
# <Axes: xlabel='Family_Income', ylabel='count'>

# %%
sns.countplot(x="Internet_Access", data=df, palette="cool")
# Out:
# <Axes: xlabel='Internet_Access', ylabel='count'>

# %% [markdown]
# ## Box Plot

# %%
plt.figure(figsize=(8,6))
sns.set_style('whitegrid')
sns.boxplot(x='Peer_Influence',y='Exam_Score',data=df, hue='Gender', palette='Set2')
# Out:
# <Axes: xlabel='Peer_Influence', ylabel='Exam_Score'>

# %% [markdown]
# ## Violin Plot

# %%
plt.figure(figsize=(8,6))
sns.violinplot(x='Learning_Disabilities',y='Exam_Score',data=df, hue='Gender', palette='Accent')
# Out:
# <Axes: xlabel='Learning_Disabilities', ylabel='Exam_Score'>

# %% [markdown]
# ## Strip Plot

# %%
plt.figure(figsize=(8,6))
sns.stripplot(x='Distance_from_Home',y='Exam_Score',data=df, hue='Gender', dodge=True, palette='autumn')
# Out:
# <Axes: xlabel='Distance_from_Home', ylabel='Exam_Score'>

# %% [markdown]
# # Matrix Plots

# %% [markdown]
# ## Heat Maps

# %% [markdown]
# ### Corelation Method

# %%
cordf = df.corr(numeric_only=True)
sns.heatmap(cordf, annot=True, cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# ### Pivot Table Method

# %%
pvdf = df.pivot_table(index='Parental_Involvement', columns='Parental_Education_Level', values='Exam_Score')

# Define the desired order for index and columns
parental_involvement_order = ['Low', 'Medium', 'High']
parental_education_order = ['High School', 'College', 'Postgraduate']

# Reindex the DataFrame
pvdf = pvdf.reindex(index=parental_involvement_order, columns=parental_education_order)


# in good ordered data YOU JUST DO THIS
sns.heatmap(pvdf, cmap='Blues', linecolor='white', linewidth=1)
# Out:
# <Axes: xlabel='Parental_Education_Level', ylabel='Parental_Involvement'>
